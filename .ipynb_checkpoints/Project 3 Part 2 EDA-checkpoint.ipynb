# %%
# Standard Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_csv('Data/final_tmdb_tata_2000.csv.gz')
df2 = pd.read_csv('Data/final_tmdb_tata_2001.csv.gz')
df1.head()
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg                   NaN
# 2  tt0113092    0.0                               NaN                   NaN
# 3  tt0116391    0.0                               NaN                   NaN
# 4  tt0118694    0.0  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg                   NaN
#
#        budget                                             genres homepage  \
# 0         NaN                                                NaN      NaN
# 1  10000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...      NaN
# 2         0.0           [{'id': 878, 'name': 'Science Fiction'}]      NaN
# 3         0.0  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...      NaN
# 4    150000.0  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...      NaN
#
# ...

# %%
df2.head()
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0035423    0.0  /hfeiSfWYujh6MKhtGTXyK3DD4nN.jpg                   NaN
# 2  tt0114447    0.0                               NaN                   NaN
# 3  tt0116916    0.0  /rFpHBidSlhjflmnLu7BZilyKeQR.jpg                   NaN
# 4  tt0118589    0.0  /9NZAirJahVilTiDNCHLFcdkwkiy.jpg                   NaN
#
#        budget                                             genres homepage  \
# 0         NaN                                                NaN      NaN
# 1  48000000.0  [{'id': 10749, 'name': 'Romance'}, {'id': 14, ...      NaN
# 2         0.0  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...      NaN
# 3         0.0  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...      NaN
# 4  22000000.0  [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...      NaN
#
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1254 entries, 0 to 1253
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_id                1254 non-null   object
#  1   adult                  1253 non-null   float64
#  2   backdrop_path          713 non-null    object
#  3   belongs_to_collection  116 non-null    object
#  4   budget                 1253 non-null   float64
#  5   genres                 1253 non-null   object
#  6   homepage               64 non-null     object
#  7   id                     1253 non-null   float64
#  8   original_language      1253 non-null   object
#  9   original_title         1253 non-null   object
#  10  overview               1231 non-null   object
#  11  popularity             1253 non-null   float64
#  12  poster_path            1142 non-null   object
#  13  production_companies   1253 non-null   object
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1349 entries, 0 to 1348
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_id                1349 non-null   object
#  1   adult                  1348 non-null   float64
#  2   backdrop_path          742 non-null    object
#  3   belongs_to_collection  96 non-null     object
#  4   budget                 1348 non-null   float64
#  5   genres                 1348 non-null   object
#  6   homepage               107 non-null    object
#  7   id                     1348 non-null   float64
#  8   original_language      1348 non-null   object
#  9   original_title         1348 non-null   object
#  10  overview               1324 non-null   object
#  11  popularity             1348 non-null   float64
#  12  poster_path            1221 non-null   object
#  13  production_companies   1348 non-null   object
# ...

# %%
merged_df = pd.concat([df1,df2])
merged_df
# Out:
#         imdb_id  adult                     backdrop_path  \
# 0             0    NaN                               NaN
# 1     tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg
# 2     tt0113092    0.0                               NaN
# 3     tt0116391    0.0                               NaN
# 4     tt0118694    0.0  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg
# ...         ...    ...                               ...
# 1344  tt7797790    0.0                               NaN
# 1345  tt8665056    0.0                               NaN
# 1346  tt8795764    0.0                               NaN
# 1347  tt9071078    0.0                               NaN
# 1348  tt9212730    0.0                               NaN
#
#      belongs_to_collection      budget  \
# 0                      NaN         NaN
# 1                      NaN  10000000.0
# 2                      NaN         0.0
# 3                      NaN         0.0
# 4                      NaN    150000.0
# ...

# %%
merged_df = merged_df[(merged_df['budget']>0)|(merged_df['revenue']>0)]
merged_df
# Out:
#         imdb_id  adult                     backdrop_path  \
# 1     tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg
# 4     tt0118694    0.0  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg
# 6     tt0119273    0.0  /f5C03doOWiauu37bToKXtpgP5bS.jpg
# 11    tt0120263    0.0  /ynXVuylP8upazjz8lrqb1PEMkdR.jpg
# 12    tt0120467    0.0  /knok3mNReKqPTplnnqz7E4dd7mD.jpg
# ...         ...    ...                               ...
# 1290  tt0867181    0.0                               NaN
# 1292  tt1039952    0.0  /yTGmGjAd0gfpVK0ezoqWgx7AJkp.jpg
# 1308  tt1764172    0.0                               NaN
# 1322  tt2957918    0.0                               NaN
# 1328  tt3314212    0.0                               NaN
#
#                                   belongs_to_collection      budget  \
# 1                                                   NaN  10000000.0
# 4                                                   NaN    150000.0
# 6     {'id': 141086, 'name': 'Heavy Metal Collection...  15000000.0
# ...

# %%
# label order
label_order = merged_df['certification'].value_counts().index

# Define a MatplotLib ax (plot) object using seaborn.countplot()
ax = sns.countplot(data=merged_df,
                   x='certification',
                   order=label_order)

# Title
ax.set_title('Count of certification ratings')
# Out:
# Text(0.5, 1.0, 'Count of certification ratings')

# %%
avg_revenue = merged_df.groupby('certification')['revenue'].mean().reset_index()
avg_revenue
# Out:
#   certification       revenue
# 0             G  1.173648e+08
# 1            NR  1.682004e+07
# 2            PG  1.106791e+08
# 3         PG-13  9.797167e+07
# 4             R  3.031018e+07

# %%
avg_revenue = merged_df.groupby('certification')['budget'].mean()
avg_revenue
# Out:
# certification
# G        3.813333e+07
# NR       9.658814e+06
# PG       4.482849e+07
# PG-13    4.332450e+07
# R        1.843335e+07
# Name: budget, dtype: float64
