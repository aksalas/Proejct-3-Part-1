# %%
# Standard Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_csv('Data/final_tmdb_tata_2018.csv.gz')
df2 = pd.read_csv('Data/final_tmdb_tata_2019.csv.gz')
df1.head()
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0069049    0.0  /wXUcSJG6dqNKgIRgqYqX98UA1wz.jpg                   NaN
# 2  tt0192528    0.0  /gkBxjhtVEqgxOiRwRfWw1j7ez6K.jpg                   NaN
# 3  tt0360556    0.0  /7oy4miyq4WYYy0xtX6lbNVPrEsr.jpg                   NaN
# 4  tt0365545    0.0  /ljTYcQ3pkzYF52Z8ev1Z1UThnPy.jpg                   NaN
#
#        budget                                             genres  \
# 0         NaN                                                NaN
# 1  12000000.0                      [{'id': 18, 'name': 'Drama'}]
# 2   5000000.0                      [{'id': 18, 'name': 'Drama'}]
# 3         0.0  [{'id': 18, 'name': 'Drama'}, {'id': 878, 'nam...
# 4         0.0  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
#
#                                     homepage        id original_language  \
# ...

# %%
df2.head()
# Out:
#      imdb_id  adult                     backdrop_path  \
# 0          0    NaN                               NaN
# 1  tt0385887    0.0  /xMHeU84wLQ9uH9acJ0oPgdii9wO.jpg
# 2  tt0437086    0.0  /8RKBHHRqOMOLh5qW3sS6TSFTd8h.jpg
# 3  tt0441881    0.0  /7uacpbrJd9g9xSTLgfyg1NwkAiu.jpg
# 4  tt0448115    0.0  /o7JVhqMmrex1TPbmuxl8YXVlcfl.jpg
#
#                                belongs_to_collection       budget  \
# 0                                                NaN          NaN
# 1                                                NaN   26000000.0
# 2                                                NaN  170000000.0
# 3                                                NaN   23934823.0
# 4  {'id': 724848, 'name': 'Shazam! Collection', '...   80000000.0
#
#                                               genres  \
# 0                                                NaN
# 1  [{'id': 18, 'name': 'Drama'}, {'id': 53, 'name...
# 2  [{'id': 28, 'name': 'Action'}, {'id': 878, 'na...
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4695 entries, 0 to 4694
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_id                4695 non-null   object
#  1   adult                  4694 non-null   float64
#  2   backdrop_path          3656 non-null   object
#  3   belongs_to_collection  281 non-null    object
#  4   budget                 4694 non-null   float64
#  5   genres                 4694 non-null   object
#  6   homepage               1274 non-null   object
#  7   id                     4694 non-null   float64
#  8   original_language      4694 non-null   object
#  9   original_title         4694 non-null   object
#  10  overview               4617 non-null   object
#  11  popularity             4694 non-null   float64
#  12  poster_path            4607 non-null   object
#  13  production_companies   4694 non-null   object
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4910 entries, 0 to 4909
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_id                4910 non-null   object
#  1   adult                  4909 non-null   float64
#  2   backdrop_path          3911 non-null   object
#  3   belongs_to_collection  298 non-null    object
#  4   budget                 4909 non-null   float64
#  5   genres                 4909 non-null   object
#  6   homepage               1249 non-null   object
#  7   id                     4909 non-null   float64
#  8   original_language      4909 non-null   object
#  9   original_title         4909 non-null   object
#  10  overview               4812 non-null   object
#  11  popularity             4909 non-null   float64
#  12  poster_path            4842 non-null   object
#  13  production_companies   4909 non-null   object
# ...

# %%
merged_df = pd.concat([df1,df2])
merged_df
# Out:
#         imdb_id  adult                     backdrop_path  \
# 0             0    NaN                               NaN
# 1     tt0069049    0.0  /wXUcSJG6dqNKgIRgqYqX98UA1wz.jpg
# 2     tt0192528    0.0  /gkBxjhtVEqgxOiRwRfWw1j7ez6K.jpg
# 3     tt0360556    0.0  /7oy4miyq4WYYy0xtX6lbNVPrEsr.jpg
# 4     tt0365545    0.0  /ljTYcQ3pkzYF52Z8ev1Z1UThnPy.jpg
# ...         ...    ...                               ...
# 4905  tt9906644    0.0  /htoReVItKtolso5VJqFqJDBaOwm.jpg
# 4906  tt9913660    0.0   /z6YpkQiWLnRKl5yQD9dSiPDFWN.jpg
# 4907  tt9913872    0.0  /a0kySBmMZ77AqmNA3pDu45GsbCp.jpg
# 4908  tt9914942    0.0  /tjHUeULyw2vtS1DXFp0OHfhUzRX.jpg
# 4909  tt9915872    0.0                               NaN
#
#      belongs_to_collection      budget  \
# 0                      NaN         NaN
# 1                      NaN  12000000.0
# 2                      NaN   5000000.0
# 3                      NaN         0.0
# 4                      NaN         0.0
# ...

# %%
merged_df = merged_df[(merged_df['budget']>0)|(merged_df['revenue']>0)]
merged_df
# Out:
#          imdb_id  adult                     backdrop_path  \
# 1      tt0069049    0.0  /wXUcSJG6dqNKgIRgqYqX98UA1wz.jpg
# 2      tt0192528    0.0  /gkBxjhtVEqgxOiRwRfWw1j7ez6K.jpg
# 6      tt0859635    0.0  /lXtS4sFvOtwnFBiezzJvOMC7b9W.jpg
# 12    tt10028708    0.0  /jzbUaEPaPq8pHpJMAx3lhrCROCU.jpg
# 31    tt10322172    0.0  /wi2JEpSs0u5863HRWQES9HW9qsQ.jpg
# ...          ...    ...                               ...
# 4861   tt9875852    0.0  /tqawzOvbpiFzd4koL0Uo8NEXaDW.jpg
# 4863   tt9877340    0.0  /n9ba261Dh7lQNsbW1p3BcFJsaIh.jpg
# 4868   tt9881572    0.0                               NaN
# 4884   tt9894470    0.0  /h5sUE9jqoYrjsFjANJXL0gpZGye.jpg
# 4899   tt9903890    0.0                               NaN
#
#                                   belongs_to_collection      budget  \
# 1                                                   NaN  12000000.0
# 2                                                   NaN   5000000.0
# ...

# %%
# label order
label_order = merged_df['certification'].value_counts().index

# Define a MatplotLib ax (plot) object using seaborn.countplot()
ax = sns.countplot(data=merged_df,
                   x='certification',
                   order=label_order)

# Title
ax.set_title('Count of certification ratings')
# Out:
# Text(0.5, 1.0, 'Count of certification ratings')

# %%
avg_revenue = merged_df.groupby('certification')['revenue'].mean().reset_index()
avg_revenue
# Out:
#   certification       revenue
# 0             G  1.180812e+08
# 1         NC-17  3.466667e+04
# 2            NR  4.612883e+06
# 3            PG  1.750453e+08
# 4         PG-13  1.524617e+08
# 5             R  3.858304e+07

# %%
avg_revenue = merged_df.groupby('certification')['budget'].mean()
avg_revenue
# Out:
# certification
# G        1.777607e+07
# NC-17    3.766667e+04
# NR       2.490935e+06
# PG       4.871534e+07
# PG-13    3.842800e+07
# R        1.417075e+07
# Name: budget, dtype: float64
